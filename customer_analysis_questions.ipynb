# %% [markdown]
# # Customer Data Analysis Questions
# ## Banking Customer Insights

# %%
import duckdb
import pandas as pd
import matplotlib.pyplot as plt

con = duckdb.connect('data.duckdb', read_only=True)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Question 1: Customer Demographics
# **What is the distribution of customers by bank? Which bank has more customers?**

# %%
# Your SQL query here
query = """
SELECT 
    bank_name,
    COUNT(*) as customer_count
FROM customers
GROUP BY bank_name
ORDER BY customer_count DESC
"""
con.execute(query).df()

# %% [markdown]
# ## Question 2: Age Analysis
# **What is the average age of customers? How many customers are retired vs working?**

# %%
# Calculate age and analyze occupation
query = """
-- Write your query here
"""
# con.execute(query).df()

# %% [markdown]
# ## Question 3: Income Distribution
# **What is the income distribution across different occupations? Which occupation has the highest average income?**

# %%
# Analyze income by occupation
query = """
-- Write your query here
"""
# con.execute(query).df()

# %% [markdown]
# ## Question 4: Source of Funds
# **What are the primary sources of funds for customers? How does this vary by age group?**

# %%
# Analyze source of funds
query = """
-- Write your query here
"""
# con.execute(query).df()

# %% [markdown]
# ## Question 5: Gender Distribution
# **What is the gender distribution across banks? Is there any income gap between genders?**

# %%
# Analyze gender distribution and income
query = """
-- Write your query here
"""
# con.execute(query).df()

# %% [markdown]
# ## Question 6: Geographic Analysis
# **Which postcodes or regions have the most customers? Are there any patterns?**

# %%
# Analyze geographic distribution
query = """
-- Write your query here
"""
# con.execute(query).df()

# %% [markdown]
# ## Question 7: KYC Compliance
# **How many customers have outdated KYC (Know Your Customer) information? (last_kyc_date > 3 years ago)**

# %%
# Check KYC compliance
query = """
-- Write your query here
"""
# con.execute(query).df()

# %% [markdown]
# ## Question 8: Document Expiry
# **How many customers have expired ID documents? Which bank has the most expired documents?**

# %%
# Check expired documents
query = """
-- Write your query here
"""
# con.execute(query).df()

# %% [markdown]
# ## Question 9: Customer Tenure
# **What is the average customer tenure (time since start_date)? Which customers are newest vs oldest?**

# %%
# Analyze customer tenure
query = """
-- Write your query here
"""
# con.execute(query).df()

# %% [markdown]
# ## Question 10: High-Value Customers
# **Who are the top 10 highest income customers? What are their characteristics (occupation, age, bank)?**

# %%
# Find high-value customers
query = """
-- Write your query here
"""
# con.execute(query).df()

# %% [markdown]
# ## Bonus Challenge Questions

# %% [markdown]
# ### Challenge 1: Risk Segmentation
# **Create customer risk segments based on: income level, occupation type, and source of funds. How many customers fall into each segment?**

# %%
# Create risk segments

# %% [markdown]
# ### Challenge 2: Churn Analysis
# **Identify customers who have an end_date (churned customers). What patterns do you see in their profiles?**

# %%
# Analyze churned customers

# %% [markdown]
# ### Challenge 3: Data Quality
# **Find records with missing or suspicious data (NULL values, unusual patterns). What percentage of data is incomplete?**

# %%
# Check data quality
